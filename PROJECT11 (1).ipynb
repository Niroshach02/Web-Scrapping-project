# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as bs
import requests
import re
import numpy as np

# %%
page = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP")
page
# Out:
# <Response [200]>

# %%
soup = bs(page.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
Price=[]
for i in p:
    a = i.text
    Price.append(a)

# %%
Price
# Out:
# ['₹37,849',
#  '₹1,22,804',
#  '₹60,950',
#  '₹37,990',
#  '₹37,890',
#  '₹47,118',
#  '₹56,990',
#  '₹92,990',
#  '₹36,990',
#  '₹36,990',
#  '₹39,990',
#  '₹59,990',
#  '₹42,990',
#  '₹38,999',
#  '₹42,990',
#  '₹79,990',
#  '₹39,990',
#  '₹40,845',
#  '₹52,950',
#  '₹1,63,739',
#  '₹47,490',
#  '₹53,970',
#  '₹59,990',
#  '₹1,40,347']

# %%
len(Price)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Model=[]
for i in p:
    a = i.text
    Model.append(a.split("-")[0])
    #b = re.findall("\w+\s\w+\sPro",a)
    #if b:
       # Processor.append(b)

# %%
Model
# Out:
# ['HP Ryzen 3 Quad Core 5300U ',
#  'HP OMEN Ryzen 7 Octa Core 5800H ',
#  'HP HP Pavilion Ryzen 5 Hexa Core 4600H ',
#  'HP Core i3 11th Gen ',
#  'HP Ryzen 3 Dual Core 3250U ',
#  'HP Ryzen 5 Hexa Core 5500U ',
#  'HP Ryzen 7 Octa Core 5700U ',
#  'HP HP Envy Ryzen 7 Octa Core 4700U ',
#  'HP Notebook PC Core i3 11th Gen ',
#  'HP Core i3 11th Gen ',
#  'HP Core i3 11th Gen ',
#  'HP Pavilion Gaming Ryzen 5 Quad Core 3550H ',
#  'HP Core i3 11th Gen ',
#  'HP 15s Ryzen 3 Dual Core 3250U ',
#  'HP Core i3 11th Gen ',
#  'HP Pavilion Gaming Ryzen 7 Octa Core 5800H ',
#  'HP Core i3 11th Gen ',
#  'HP Core i3 11th Gen ',
#  'HP Core i5 11th Gen ',
#  'HP OMEN Ryzen 9 Octa Core 5900H ',
#  'HP Ryzen 5 Hexa Core 5500U ',
#  'HP Pavilion x360 Core i3 11th Gen ',
#  'HP Pavilion Ryzen 5 Hexa Core 5600H ',
#  'HP OMEN Ryzen 7 Octa Core 5800H ']

# %%
len(Model)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Processor=[]
for i in p:
    a = i.text
    #b=Processor.append(a.split("- (")[0][2::1])
    #b = re.findall("HP\s\w+\s\w+\s\w+\s\w+",a)
    #if b:
        #Processor.append(b)
    Processor.append(a.split("-")[0][2::1])

# %%
Processor
# Out:
# [' Ryzen 3 Quad Core 5300U ',
#  ' OMEN Ryzen 7 Octa Core 5800H ',
#  ' HP Pavilion Ryzen 5 Hexa Core 4600H ',
#  ' Core i3 11th Gen ',
#  ' Ryzen 3 Dual Core 3250U ',
#  ' Ryzen 5 Hexa Core 5500U ',
#  ' Ryzen 7 Octa Core 5700U ',
#  ' HP Envy Ryzen 7 Octa Core 4700U ',
#  ' Notebook PC Core i3 11th Gen ',
#  ' Core i3 11th Gen ',
#  ' Core i3 11th Gen ',
#  ' Pavilion Gaming Ryzen 5 Quad Core 3550H ',
#  ' Core i3 11th Gen ',
#  ' 15s Ryzen 3 Dual Core 3250U ',
#  ' Core i3 11th Gen ',
#  ' Pavilion Gaming Ryzen 7 Octa Core 5800H ',
#  ' Core i3 11th Gen ',
#  ' Core i3 11th Gen ',
#  ' Core i5 11th Gen ',
#  ' OMEN Ryzen 9 Octa Core 5900H ',
#  ' Ryzen 5 Hexa Core 5500U ',
#  ' Pavilion x360 Core i3 11th Gen ',
#  ' Pavilion Ryzen 5 Hexa Core 5600H ',
#  ' OMEN Ryzen 7 Octa Core 5800H ']

# %%
len(Processor)
# Out:
# 24

# %%
p = soup.find_all("li",class_="rgWa7D")
Operating_system =[]
for i in p:
    a = i.text
            #Operating_system .append(a.split(" ")[2:7])
    b=re.findall('\w+\s\d+\sOperating System',a)
    if b:
        Operating_system .append(b)

# %%
Operating_system
# Out:
# [['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System']]

# %%
len(Operating_system)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Ram=[]
for i in p:
    a = i.text
    #Ram.append(a.split("(")[1].split("/")[0])
    b=re.findall("\w+\sGB/",a)
    if b:
        Ram.append(b)

# %%
Ram
# Out:
# [['8 GB/'],
#  ['16 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['16 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['16 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['16 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['8 GB/'],
#  ['16 GB/']]

# %%
len(Ram)
# Out:
# 24

# %%
#p = soup.find_all("div",class_="_4rR01T")
#Rom=[]
#for i in p:
    #a = i.text
    #Rom.append(a)
    #b=re.findall("\d+\s\w+/(\d+\s\w+\sSSD)",a)
    #b=a.split(".")
    #b=re.findall("\d+\s\w+\s\w+",a)
    #c=b[::1]
    #if c:
        #Rom.append(c[0])
    #if b:
        #Rom.append(b[0])
        
            
    #else:
        #Rom.append(np.nan)
p = soup.find_all("li",class_="rgWa7D")
Rom=[]
for i in p:
    a = i.text
        #Rom.append(a)
        #b=re.findall("\d+\s\w+/(\d+\s\w+)\sSSD",a)
    b=re.findall("(\d\sTB\sHDD|\d+\sGB\sSSD)",a)
    c=re.findall("(\d+\sGB\sSSD)",a)
    d=re.findall("(\d\sTB\sHDD)",a)
    if b:
        Rom.append(b)
    elif c:
        Rom.append(c)
    elif d:
        Rom.append(d)

# %%
Rom
# Out:
# [['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['256 GB SSD'],
#  ['256 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['1 TB HDD'],
#  ['256 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD'],
#  ['512 GB SSD']]

# %%
len(Rom)
# Out:
# 21

# %%
#Rom.extend(["256 GB","256 GB","256 GB"])

# %%
p = soup.find_all("li",class_="rgWa7D")
Screen_size=[]
for i in p:
    a = i.text
    b=re.findall("\d+.\d+\scm",a)
    if b:
        Screen_size.append(b[0])

# %%
Screen_size
# Out:
# ['35.56 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '33.78 cm',
#  '39.62 cm',
#  '39.62 cm']

# %%
len(Screen_size)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Brand=[]
for i in p:
    a = i.text
    Brand.append(a.split()[0])

# %%
Brand
# Out:
# ['HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP',
#  'HP']

# %%
Website=[]
for i in range(1,25):
    list[print("FLIPCART")]
    Website.append("FLIPCART")
# Out:
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART

# %%
Website
# Out:
# ['FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART',
#  'FLIPCART']

# %%
import pandas as pd
dfFH = pd.DataFrame({
    "Brand":Brand,
     "Model":Model,
    "Processor":Processor,
    "Ram":Ram,
    "Operating_system":Operating_system,
    "Rom":Rom,
    "Screen_size":Screen_size,
    "Price":Price,
    "Website":Website
})

# %%
dfFH
# Out:
#    Brand                                              Model  \
# 0     HP                               HP Core i3 11th Gen
# 1     HP                        HP Ryzen 3 Dual Core 3250U
# 2     HP                        HP Ryzen 5 Hexa Core 5500U
# 3     HP            HP HP Pavilion Ryzen 5 Hexa Core 4600H
# 4     HP                               HP Core i3 11th Gen
# 5     HP                               HP Core i3 11th Gen
# 6     HP                   HP Notebook PC Core i3 11th Gen
# 7     HP                               HP Core i3 11th Gen
# 8     HP                               HP Core i3 11th Gen
# 9     HP                               HP Core i3 11th Gen
# 10    HP                    HP 15s Ryzen 3 Dual Core 3250U
# 11    HP                               HP Core i5 11th Gen
# 12    HP                 HP Pavilion x360 Core i3 11th Gen
# 13    HP                        HP Ryzen 7 Octa Core 5700U
# 14    HP               HP Pavilion Ryzen 5 Hexa Core 5600H
# ...

# %%
text="""https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP&page="""
text
# Out:
# 'https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP&page='

# %%
Brand = []
Model=[]
Processor = []
Ram = []
Operating_system  = []
Rom=[]
Screen_size = []
Price =  []
for i in range(1,4):
    url = text+str(i)
    print(url)
    page = requests.get(url)
    soup = bs(page.text)
    p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
    for i in p:
        a = i.text
        Price.append(a)
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        Model.append(a.split("-")[0])
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        #Processor.append(a)
        #Processor.append(a.split("-")[0][2::1])
        #b = re.findall("HP\s\w+\s\w+\s\w+\s\w+",a)
        #b = re.findall("\w+\s\w+\sPro",a)
       # if b:
           # Processor.append(b)
        Processor.append(a.split("-")[0][2::1])
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
            #Operating_system .append(a.split(" ")[2:7])
        b=re.findall('\w+\s\d+\sOperating System',a)
        if b:
            Operating_system .append(b)
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        #Ram.append(a.split("(")[1].split("/")[0])
        b=re.findall("\w+\sGB/",a)
        if b:
            Ram.append(b)
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
        #Rom.append(a)
        #b=re.findall("\d+\s\w+/(\d+\s\w+)\sSSD",a)
        b=re.findall("(\d\sTB\sHDD|\d+\sGB\sSSD)",a)
        c=re.findall("(\d+\sGB\sSSD)",a)
        d=re.findall("(\d\sTB\sHDD)",a)
        if b:
            Rom.append(b)
        elif c:
            Rom.append(c)
        elif d:
            Rom.append(d)
        #else:
            #Rom.append(np.nan)
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
        b=re.findall("\d+.\d+\scm",a)
        if b:
            Screen_size.append(b[0])
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        Brand.append(a.split()[0])
# Out:
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP&page=1
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP&page=2
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DHP&page=3

# %%
len(Brand)
# Out:
# 72

# %%
len(Model)
# Out:
# 72

# %%
len(Processor)
# Out:
# 72

# %%
len(Price)
# Out:
# 72

# %%
len(Ram)
# Out:
# 72

# %%
#Ram.insert(71,"16 GB")

# %%
#Ram.insert(71,np.nan)

# %%
#Rom.remove("16 GB")

# %%
len(Rom)
# Out:
# 64

# %%
#Rom.insert(71,"256 GB")

# %%
len(Operating_system)
# Out:
# 72

# %%
#Operating_system.insert(71,"Windows 11")

# %%
len(Screen_size)
# Out:
# 72

# %%
Website=[]
for i in range(1,73):
    list[print("FLIPCART")]
    Website.append("FLIPCART")
# Out:
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART

# %%
import pandas as pd
dfFH = pd.DataFrame({
    "Brand":Brand,
     "Model":Model,
    "Processor":Processor,
    "Ram":Ram,
    "Operating_system":Operating_system,
    "Rom":Rom,
    "Screen_size":Screen_size,
    "Price":Price,
    "Website":Website
})

# %%
dfFH
# Out:
#    Brand                                           Model  \
# 0     HP                            HP Core i3 11th Gen
# 1     HP                     HP Ryzen 3 Dual Core 3250U
# 2     HP                     HP Ryzen 5 Hexa Core 5500U
# 3     HP                            HP Core i3 11th Gen
# 4     HP         HP HP Pavilion Ryzen 5 Hexa Core 4600H
# ..   ...                                             ...
# 67    HP                                  HP APU Pro A4
# 68    HP                HP OMEN Ryzen 5 Hexa Core 5600H
# 69    HP  HP Pavilion x360 Convertible Core i3 11th Gen
# 70    HP                            HP Core i5 11th Gen
# 71    HP                        HP 15s Core i3 10th Gen
#
#                                        Processor      Ram  \
# 0                              Core i3 11th Gen   [8 GB/]
# 1                       Ryzen 3 Dual Core 3250U   [8 GB/]
# 2                       Ryzen 5 Hexa Core 5500U   [8 GB/]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup as bs
import requests
import re
import numpy as np

# %%
page = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DDELL")
page
# Out:
# <Response [200]>

# %%
soup = bs(page.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
Price=[]
for i in p:
    a = i.text
    Price.append(a)

# %%
Price
# Out:
# ['₹34,990',
#  '₹29,990',
#  '₹35,990',
#  '₹39,990',
#  '₹31,990',
#  '₹30,990',
#  '₹29,990',
#  '₹49,990',
#  '₹46,990',
#  '₹38,890',
#  '₹35,990',
#  '₹41,190',
#  '₹37,790',
#  '₹56,190',
#  '₹35,990',
#  '₹39,990',
#  '₹35,590',
#  '₹67,690',
#  '₹34,990',
#  '₹39,890',
#  '₹36,990',
#  '₹70,990',
#  '₹40,990',
#  '₹38,990']

# %%
len(Price)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Model=[]
for i in p:
        a = i.text
        Model.append(a.split("-")[0])

# %%
Model
# Out:
# ['DELL Vostro Core i3 10th Gen ',
#  'DELL Inspiron Athlon Dual Core 3050U ',
#  'DELL Vostro Core i3 11th Gen ',
#  'DELL Vostro Core i3 10th Gen ',
#  'DELL Inspiron Ryzen 3 Dual Core 3250U ',
#  'DELL Inspiron Pentium Silver ',
#  'DELL Vostro Ryzen 3 Dual Core R3',
#  'DELL Vostro Core i5 11th Gen ',
#  'DELL Inspiron Core i3 11th Gen ',
#  'DELL Inspiron Ryzen 3 Dual Core 3250U ',
#  'DELL Ryzen 3 Dual Core 3250U ',
#  'DELL Vostro Core i3 11th Gen ',
#  'DELL Vostro Core i3 11th Gen ',
#  'DELL Inspiron Core i5 11th Gen ',
#  'DELL Vostro Core i3 11th Gen ',
#  'DELL Core i3 10th Gen ',
#  'DELL Inspiron Ryzen 3 Dual Core 3250U ',
#  'DELL Inspiron Core i5 11th Gen ',
#  'DELL Vostro Core i3 10th Gen ',
#  'DELL Vostro Core i3 10th Gen ',
#  'DELL Inspiron Ryzen 3 Dual Core 3250U ',
#  'DELL Ryzen 5 Hexa Core 5600H ',
#  'DELL Inspiron Core i3 11th Gen ',
#  'DELL Vostro Core i3 10th Gen ']

# %%
len(Model)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Processor=[]
for i in p:
    a = i.text
        #Processor.append(a)
        #Processor.append(a.split("-")[0][2::1])
    #b = re.findall("HP\s\w+\s\w+\s\w+\s\w+",a)
        #b = re.findall("\w+\s\w+\sPro",a)
    #if b:
       # Processor.append(b)
    Processor.append(a.split("-")[0][4::1])

# %%
Processor
# Out:
# [' Vostro Core i3 10th Gen ',
#  ' Inspiron Athlon Dual Core 3050U ',
#  ' Vostro Core i3 11th Gen ',
#  ' Vostro Core i3 10th Gen ',
#  ' Inspiron Ryzen 3 Dual Core 3250U ',
#  ' Inspiron Pentium Silver ',
#  ' Vostro Ryzen 3 Dual Core R3',
#  ' Vostro Core i5 11th Gen ',
#  ' Inspiron Core i3 11th Gen ',
#  ' Inspiron Ryzen 3 Dual Core 3250U ',
#  ' Ryzen 3 Dual Core 3250U ',
#  ' Vostro Core i3 11th Gen ',
#  ' Vostro Core i3 11th Gen ',
#  ' Inspiron Core i5 11th Gen ',
#  ' Vostro Core i3 11th Gen ',
#  ' Core i3 10th Gen ',
#  ' Inspiron Ryzen 3 Dual Core 3250U ',
#  ' Inspiron Core i5 11th Gen ',
#  ' Vostro Core i3 10th Gen ',
#  ' Vostro Core i3 10th Gen ',
#  ' Inspiron Ryzen 3 Dual Core 3250U ',
#  ' Ryzen 5 Hexa Core 5600H ',
#  ' Inspiron Core i3 11th Gen ',
#  ' Vostro Core i3 10th Gen ']

# %%
len(Processor)
# Out:
# 24

# %%
p = soup.find_all("li",class_="rgWa7D")
Operating_system =[]
for i in p:
    a = i.text
    #Operating_system .append(a.split("/")[2])
    b=re.findall('\w+\s\d+\sOperating System',a)
    if b:
        Operating_system .append(b)

# %%
Operating_system
# Out:
# [['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 10 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System'],
#  ['Windows 11 Operating System']]

# %%
len(Operating_system)
# Out:
# 24

# %%
p = soup.find_all("li",class_="rgWa7D")
Ram=[]
for i in p:
    a = i.text
    #Ram.append(a.split("(")[1].split("/")[0])
    b=re.findall("(\d+\sGB\s\w+)\sRAM",a)
    if b:
        Ram.append(b)

# %%
Ram
# Out:
# [['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['4 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['16 GB DDR4'],
#  ['4 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4'],
#  ['8 GB DDR4']]

# %%
len(Ram)
# Out:
# 24

# %%
p = soup.find_all("li",class_="rgWa7D")
Rom=[]
for i in p:
        a = i.text
        #Rom.append(a)
        #b=re.findall("\d+\s\w+/(\d+\s\w+)\sSSD",a)
        b=re.findall("(\d\sTB\sHDD|\d+\sGB\sSSD)",a)
        c=re.findall("(\d+\sGB\sSSD)",a)
        d=re.findall("(\d\sTB\sHDD)",a)
        if b:
            Rom.append(b)
        elif c:
            Rom.append(c)
        elif d:
            Rom.append(d)

# %%
Rom
# Out:
# [['512 GB SSD'],
#  ['256 GB SSD'],
#  ['256 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['256 GB SSD'],
#  ['256 GB SSD'],
#  ['1 TB HDD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['256 GB SSD'],
#  ['256 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['256 GB SSD'],
#  ['256 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['256 GB SSD'],
#  ['512 GB SSD'],
#  ['1 TB HDD', '256 GB SSD'],
#  ['512 GB SSD'],
#  ['1 TB HDD'],
#  ['512 GB SSD'],
#  ['256 GB SSD'],
#  ['512 GB SSD']]

# %%
len(Rom)
# Out:
# 24

# %%
#Rom.insert(23,"512 GB")

# %%
p = soup.find_all("li",class_="rgWa7D")
Screen_size=[]
for i in p:
    a = i.text
    b=re.findall("\d+.\d+\scm",a)
    if b:
        Screen_size.append(b[0])

# %%
Screen_size
# Out:
# ['39.62 cm',
#  '39.62 cm',
#  '38.0 cm',
#  '38.0 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '39.62 cm',
#  '38.0 cm',
#  '39.62 cm',
#  '35.56 cm',
#  '39.62 cm']

# %%
len(Screen_size)
# Out:
# 24

# %%
p = soup.find_all("div",class_="_4rR01T")
Brand=[]
for i in p:
    a = i.text
    Brand.append(a.split()[0])

# %%
Brand
# Out:
# ['DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL',
#  'DELL']

# %%
len(Brand)
# Out:
# 24

# %%
Website=[]
for i in range(1,25):
    list[print("FLIPCART")]
    Website.append("FLIPCART")
# Out:
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART

# %%
text="""https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DDELL&page="""
text
# Out:
# 'https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DDELL&page='

# %%
Brand = []
Model=[]
Processor = []
Ram = []
Operating_system  = []
Rom=[]
Screen_size = []
Price =  []
for i in range(1,3):
    url = text+str(i)
    print(url)
    page = requests.get(url)
    soup = bs(page.text)
    p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
    for i in p:
        a = i.text
        Price.append(a)
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        Model.append(a.split("-")[0])
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        #Processor.append(a)
        #Processor.append(a.split("-")[0][2::1])
    #b = re.findall("HP\s\w+\s\w+\s\w+\s\w+",a)
        #b = re.findall("\w+\s\w+\sPro",a)
    #if b:
       # Processor.append(b)
        Processor.append(a.split("-")[0][4::1])
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
    #Operating_system .append(a.split("/")[2])
        b=re.findall('\w+\s\d+\sOperating System',a)
        if b:
            Operating_system .append(b)
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
    #Ram.append(a.split("(")[1].split("/")[0])
        b=re.findall("(\d+\sGB\s\w+)\sRAM",a)
        if b:
            Ram.append(b)
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
        b=re.findall("\d+.\d+\scm",a)
        if b:
            Screen_size.append(b[0]) 
    p = soup.find_all("div",class_="_4rR01T")
    for i in p:
        a = i.text
        Brand.append(a.split()[0])
    p = soup.find_all("li",class_="rgWa7D")
    for i in p:
        a = i.text
        #Rom.append(a)
        #b=re.findall("\d+\s\w+/(\d+\s\w+)\sSSD",a)
        b=re.findall("(\d\sTB\sHDD|\d+\sGB\sSSD)",a)
        c=re.findall("(\d+\sGB\sSSD)",a)
        d=re.findall("(\d\sTB\sHDD)",a)
        if b:
            Rom.append(b)
        elif c:
            Rom.append(c)
        elif d:
            Rom.append(d)
# Out:
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DDELL&page=1
# https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&p%5B%5D=facets.brand%255B%255D%3DDELL&page=2

# %%
len(Price)
# Out:
# 48

# %%
len(Model)
# Out:
# 48

# %%
len(Brand)
# Out:
# 48

# %%
len(Ram)
# Out:
# 48

# %%
#Ram.insert(328,np.nan)

# %%
#Ram.remove("8")

# %%
len(Screen_size)
# Out:
# 48

# %%
len(Processor)
# Out:
# 48

# %%
len(Operating_system)
# Out:
# 48

# %%
len(Rom)
# Out:
# 48

# %%
#Rom.extend(["512 GB","512 GB","512 GB","512 GB","512 GB","256 GB","256 GB","256 GB","256 GB","256 GB"])

# %%
#Rom.insert(37,"256 GB")

# %%
len(Operating_system)
# Out:
# 48

# %%
len(Screen_size)
# Out:
# 48

# %%
Website=[]
for i in range(1,49):
    list[print("FLIPCART")]
    Website.append("FLIPCART")
# Out:
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART
# FLIPCART

# %%
#Rom.remove("256 GB")

# %%
import pandas as pd
dfFD = pd.DataFrame({
    "Brand":Brand,
    "Model":Model,
    "Processor":Processor,
    "Ram":Ram,
    "Operating_system":Operating_system,
    "Rom":Rom,
    "Screen_size":Screen_size,
    "Price":Price,
    "Website":Website
})

# %%
dfFD
# Out:
#    Brand                                           Model  \
# 0     HP                            HP Core i3 11th Gen
# 1     HP                     HP Ryzen 3 Dual Core 3250U
# 2     HP                     HP Ryzen 5 Hexa Core 5500U
# 3     HP                            HP Core i3 11th Gen
# 4     HP         HP HP Pavilion Ryzen 5 Hexa Core 4600H
# ..   ...                                             ...
# 67    HP                                  HP APU Pro A4
# 68    HP                HP OMEN Ryzen 5 Hexa Core 5600H
# 69    HP  HP Pavilion x360 Convertible Core i3 11th Gen
# 70    HP                            HP Core i5 11th Gen
# 71    HP                        HP 15s Core i3 10th Gen
#
#                                        Processor      Ram  \
# 0                              Core i3 11th Gen   [8 GB/]
# 1                       Ryzen 3 Dual Core 3250U   [8 GB/]
# 2                       Ryzen 5 Hexa Core 5500U   [8 GB/]
# ...

# %%
dfFHD=pd.concat([dfFH,dfFD],axis=0)

# %%
len(Operating_system)
# Out:
# 48

# %%
dffhd
# Out:
#    Brand             Processor    RAM               Operating_system  \
# 0     HP         [Core i3 Pro]   8 GB  [Windows 11 Operating System]
# 1     HP         [Core i3 Pro]   8 GB  [Windows 11 Operating System]
# 2     HP       [Dual Core Pro]   8 GB  [Windows 11 Operating System]
# 3     HP       [Octa Core Pro]  16 GB  [Windows 11 Operating System]
# 4     HP       [Hexa Core Pro]   8 GB  [Windows 11 Operating System]
# 5     HP         [Core i3 Pro]   8 GB  [Windows 10 Operating System]
# 6     HP         [Core i3 Pro]   8 GB  [Windows 11 Operating System]
# 7     HP       [Octa Core Pro]  16 GB  [Windows 11 Operating System]
# 8     HP       [Dual Core Pro]   8 GB  [Windows 10 Operating System]
# 9     HP       [Dual Core Pro]   8 GB  [Windows 11 Operating System]
# 10    HP         [Core i3 Pro]   8 GB  [Windows 11 Operating System]
# 11    HP       [Quad Core Pro]   8 GB  [Windows 10 Operating System]
# 12    HP         [Core i3 Pro]   8 GB  [Windows 11 Operating System]
# ...
